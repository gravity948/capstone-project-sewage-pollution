# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('pollution_risk_forecasting.csv')
df
# Out:
#               EUBWID               label          predictedAt  \
# 0      ukc1101-06000  Seaton Carew North  2022-04-28T08:30:00
# 1      ukc1101-06000  Seaton Carew North  2022-04-29T08:30:00
# 2      ukc1101-06000  Seaton Carew North  2022-04-30T08:30:00
# 3      ukc1101-06000  Seaton Carew North  2022-05-04T08:30:00
# 4      ukc1101-06000  Seaton Carew North  2022-05-05T08:30:00
# ...              ...                 ...                  ...
# 63641  ukk4307-33900        Westward Ho!  2022-09-26T08:30:00
# 63642  ukk4307-33900        Westward Ho!  2022-09-27T08:30:00
# 63643  ukk4307-33900        Westward Ho!  2022-09-28T08:30:00
# 63644  ukk4307-33900        Westward Ho!  2022-09-29T08:30:00
# 63645  ukk4307-33900        Westward Ho!  2022-09-30T08:30:00
#
#                publishedAt            expiresAt  \
# 0      2022-04-28T08:40:18  2022-04-29T08:29:00
# 1      2022-04-29T08:40:12  2022-04-30T08:29:00
# 2      2022-05-03T15:56:23  2022-05-01T08:29:00
# ...

# %%
riskLevelLabel_counts = df["riskLevelLabel"].value_counts()
riskLevelLabel_counts
# Out:
# normal       62302
# increased     1344
# Name: riskLevelLabel, dtype: int64

# %%
riskLevelLabel_counts.plot(kind='bar', figsize=(10,5))
plt.show()

# %%
increased_labels = df.loc[df["riskLevelLabel"] == "increased", "label"].unique()
increased_labels
# Out:
# array(['Seaton Carew North', 'Seaton Carew Centre',
#        'Redcar Lifeboat Station', 'Redcar Granville', 'Redcar Stray',
#        'Marske Sands', 'Saltburn', 'Seaham Hall Beach', 'Seaham Beach',
#        'Crimdon', 'Spittal', 'Blyth South Beach', 'Seaton Sluice',
#        'Tynemouth Cullercoats', 'Marsden', 'Allonby',
#        'Walney Biggar Bank', 'Haverigg', 'St Bees', 'Blackpool South',
#        'Blackpool Central', 'Blackpool North', 'Bispham', 'St Annes',
#        'St Annes North', 'Morecambe South', 'Morecambe North',
#        'Cleveleys', 'Ainsdale', 'Southport', 'Meols', 'Moreton',
#        'Bridlington North Beach', 'Bridlington South Beach', 'Wilsthorpe',
#        'Fraisthorpe', 'Hornsea', 'Cleethorpes', 'Humberston Fitties',
#        'Sandsend', 'Robin Hoods Bay', 'Scarborough South Bay', 'Filey',
#        'Moggs Eye', 'Anderby', 'Chapel St Leonards', 'Ingoldmells South',
#        'Heacham', 'Hunstanton Main Beach', 'Hunstanton (Old Hunstanton)',
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
