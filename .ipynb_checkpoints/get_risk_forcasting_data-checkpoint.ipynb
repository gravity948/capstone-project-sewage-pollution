# %%
import pandas as pd

# %%
riskforecasting = pd.read_csv('~data/pollution_risk_forecasting_raw.csv')
riskforecasting = riskforecasting[['label', 'predictedAt', 'warning', 'riskLevelLabel']]
riskforecasting.columns = ['site', 'time', 'warning', 'riskLevelLabel']
riskforecasting = riskforecasting[(riskforecasting['time'] >= '2022-03-01') & (riskforecasting['time'] <= '2022-10-31')]
riskforecasting['time'] = pd.to_datetime(riskforecasting['time']).dt.date
riskforecasting
# Out:
#                      site        time  \
# 0      Seaton Carew North  2022-04-28
# 1      Seaton Carew North  2022-04-29
# 2      Seaton Carew North  2022-04-30
# 3      Seaton Carew North  2022-05-04
# 4      Seaton Carew North  2022-05-05
# ...                   ...         ...
# 69574        Westward Ho!  2022-09-26
# 69575        Westward Ho!  2022-09-27
# 69576        Westward Ho!  2022-09-28
# 69577        Westward Ho!  2022-09-29
# 69578        Westward Ho!  2022-09-30
#
#                                         warning riskLevelLabel
# 0      Pollution RIsk Forecasts will start soon         normal
# 1      Pollution RIsk Forecasts will start soon         normal
# 2      Pollution RIsk Forecasts will start soon         normal
# 3                          No warnings in place         normal
# 4                          No warnings in place         normal
# ...                                         ...            ...
# 69574           No pollution incidents reported         normal
# 69575           No pollution incidents reported         normal
# 69576           No pollution incidents reported         normal
# 69577           No pollution incidents reported         normal
# 69578           No pollution incidents reported         normal
#
# [63624 rows x 4 columns]

# %%
riskforecasting = riskforecasting.sort_values(by=['site', 'time', 'riskLevelLabel'], ascending=[True, True, True])
riskforecasting = riskforecasting.drop_duplicates(subset=['site', 'time'], keep='first')
riskforecasting.reset_index(drop=True, inplace=True)
riskforecasting
# Out:
#             site        time                                   warning  \
# 0       Ainsdale  2022-04-28  Pollution RIsk Forecasts will start soon
# 1       Ainsdale  2022-04-29  Pollution RIsk Forecasts will start soon
# 2       Ainsdale  2022-04-30  Pollution RIsk Forecasts will start soon
# 3       Ainsdale  2022-05-04                      No warnings in place
# 4       Ainsdale  2022-05-05                      No warnings in place
# ...          ...         ...                                       ...
# 63573  Yaverland  2022-09-26           No pollution incidents reported
# 63574  Yaverland  2022-09-27           No pollution incidents reported
# 63575  Yaverland  2022-09-28           No pollution incidents reported
# 63576  Yaverland  2022-09-29           No pollution incidents reported
# 63577  Yaverland  2022-09-30           No pollution incidents reported
#
#       riskLevelLabel
# 0             normal
# 1             normal
# 2             normal
# 3             normal
# 4             normal
# ...              ...
# 63573         normal
# 63574         normal
# 63575         normal
# 63576         normal
# 63577         normal
#
# [63578 rows x 4 columns]

# %%
riskforecasting.to_csv('~data/pollution_risk_forecasting.csv', index=False)
