# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.stats import pearsonr
from matplotlib.ticker import StrMethodFormatter

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
sample = pd.read_csv('Datasets/Bathing_water_data/samples.csv')
sample = sample[["label","sampleTime","intestinalEnterococciCount","escherichiaColiCount"]]
sample['sampleTime'] = sample['sampleTime'].str[:10]
sample = sample.rename(columns={'label': 'site', 'sampleTime': 'time'})
sample
# Out:
#                     site        time  intestinalEnterococciCount  \
# 0     Seaton Carew North  2022-05-06                          18
# 1     Seaton Carew North  2022-05-19                          45
# 2     Seaton Carew North  2022-05-25                         130
# 3     Seaton Carew North  2022-05-31                          10
# 4     Seaton Carew North  2022-06-08                         250
# ...                  ...         ...                         ...
# 7204        Westward Ho!  2022-08-18                          10
# 7205        Westward Ho!  2022-08-25                          10
# 7206        Westward Ho!  2022-09-08                          64
# 7207        Westward Ho!  2022-09-13                          10
# 7208        Westward Ho!  2022-09-22                          10
#
#       escherichiaColiCount
# 0                       10
# 1                       10
# 2                      310
# 3                       10
# 4                      270
# ...

# %%
riskforecasting = pd.read_csv('Datasets/Bathing_water_data/pollution_risk_forecasting.csv')
riskforecasting = riskforecasting[['label','predictedAt','warning','riskLevelLabel']]
riskforecasting['predictedAt'] = pd.to_datetime(riskforecasting.predictedAt).dt.strftime('%Y-%m-%d')
riskforecasting = riskforecasting.rename(columns={'label': 'site', 'predictedAt': 'time'})
riskforecasting
# Out:
#                      site        time  \
# 0      Seaton Carew North  2022-04-28
# 1      Seaton Carew North  2022-04-29
# 2      Seaton Carew North  2022-04-30
# 3      Seaton Carew North  2022-05-04
# 4      Seaton Carew North  2022-05-05
# ...                   ...         ...
# 63641        Westward Ho!  2022-09-26
# 63642        Westward Ho!  2022-09-27
# 63643        Westward Ho!  2022-09-28
# 63644        Westward Ho!  2022-09-29
# 63645        Westward Ho!  2022-09-30
#
#                                         warning riskLevelLabel
# 0      Pollution RIsk Forecasts will start soon         normal
# 1      Pollution RIsk Forecasts will start soon         normal
# 2      Pollution RIsk Forecasts will start soon         normal
# 3                          No warnings in place         normal
# 4                          No warnings in place         normal
# ...                                         ...            ...
# ...

# %%
cope = pd.read_csv('Datasets/copernicus_data_nrt_l4.csv')
cope = cope[["site","time","SPM","TUR","CHL"]]
cope
# Out:
#                       site        time        SPM        TUR       CHL
# 0       Seaton Carew North  2022-01-03        NaN        NaN       NaN
# 1       Seaton Carew North  2022-01-04  15.024445  24.266914  9.183625
# 2       Seaton Carew North  2022-01-05        NaN        NaN       NaN
# 3       Seaton Carew North  2022-01-06        NaN        NaN       NaN
# 4       Seaton Carew North  2022-01-07        NaN        NaN       NaN
# ...                    ...         ...        ...        ...       ...
# 120825        Westward Ho!  2022-10-25        NaN        NaN       NaN
# 120826        Westward Ho!  2022-10-26        NaN        NaN       NaN
# 120827        Westward Ho!  2022-10-29        NaN        NaN       NaN
# 120828        Westward Ho!  2022-10-30        NaN        NaN       NaN
# 120829        Westward Ho!  2022-10-31        NaN        NaN       NaN
#
# [120830 rows x 5 columns]

# %% [markdown]
# ## Bacteria&Ecoli count vs. SPM&TUR&CHL

# %%
df = pd.merge(sample, cope, on=['site','time'])
df = df.dropna()
df = df.rename({'intestinalEnterococciCount': 'IE_count', 'escherichiaColiCount': 'EC_count'}, axis=1)  # new method
df
# Out:
#                     site        time  IE_count  EC_count        SPM  \
# 1     Seaton Carew North  2022-05-19        45        10  10.335602
# 3     Seaton Carew North  2022-05-31        10        10   2.788016
# 4     Seaton Carew North  2022-06-08       250       270   0.974277
# 5     Seaton Carew North  2022-06-23        18        10   3.691690
# 7     Seaton Carew North  2022-07-05       170        10   8.476042
# ...                  ...         ...       ...       ...        ...
# 7065             Shaldon  2022-07-13        27        18   0.760915
# 7098       Hartland Quay  2022-06-06        10        10   0.678526
# 7099       Hartland Quay  2022-06-23        10        10   0.686622
# 7100       Hartland Quay  2022-07-08        10        10   0.846511
# 7102       Hartland Quay  2022-08-02        10        10   0.843629
#
#             TUR        CHL
# 1     16.668087  11.645728
# 3      4.778587   8.509363
# 4      1.720897   8.066384
# 5      6.155658   6.110140
# ...

# %% [markdown]
# ### Correlations

# %%
methods = ['pearson', 'kendall', 'spearman']
corr_lst = []
for m in methods:
    corr_lst.append(df.corr(method = m).loc[["IE_count", "EC_count"],["SPM", "TUR", "CHL"]])
corr_df = pd.concat(corr_lst, keys=methods)
corr_df
# Out:
#                         SPM       TUR       CHL
# pearson  IE_count -0.006647 -0.002926 -0.015736
#          EC_count -0.016863 -0.014122  0.016209
# kendall  IE_count  0.092896  0.092977  0.074608
#          EC_count  0.129165  0.130390  0.113917
# spearman IE_count  0.123598  0.123717  0.098399
#          EC_count  0.173558  0.175441  0.149749

# %%
sns.heatmap(corr_df, annot=True)
# Out:
# <AxesSubplot:ylabel='None-None'>

# %% [markdown]
# ### Correlations(log)

# %%
log_df = np.log(df.drop(['site','time'], axis=1))
log_df.corr().loc[["IE_count", "EC_count"],["SPM", "TUR", "CHL"]]
# Out:
#                SPM      TUR       CHL
# IE_count  0.080343  0.08272  0.068815
# EC_count  0.128059  0.13177  0.144280

# %% [markdown]
# ## Risk Levels vs. SPM&TUR&CHL

# %%
df2 = pd.merge(riskforecasting, cope, on=['site','time'])
df2 = df2.dropna()
df2
# Out:
#                      site        time  \
# 1      Seaton Carew North  2022-04-29
# 3      Seaton Carew North  2022-05-04
# 13     Seaton Carew North  2022-05-14
# 15     Seaton Carew North  2022-05-16
# 18     Seaton Carew North  2022-05-19
# ...                   ...         ...
# 62595       Hartland Quay  2022-08-12
# 62600       Hartland Quay  2022-08-17
# 62607       Hartland Quay  2022-08-25
# 62609       Hartland Quay  2022-08-27
# 62612       Hartland Quay  2022-08-30
#
#                                               warning riskLevelLabel  \
# 1            Pollution RIsk Forecasts will start soon         normal
# 3                                No warnings in place         normal
# 13                               No warnings in place         normal
# 15     Advice against bathing: pollution risk warning      increased
# 18                               No warnings in place         normal
# ...                                               ...            ...
# ...

# %%
for risk in df2['riskLevelLabel'].unique():
    print(risk,'\n', df2[df2['riskLevelLabel'] == risk]['warning'].unique())
# Out:
# normal
#  ['Pollution RIsk Forecasts will start soon' 'No warnings in place'
#  'No pollution incidents reported' 'Bathing water closed'
#  'Pollution incident ended, no forecast available']
# increased
#  ['Advice against bathing: pollution risk warning'
#  'Risk of reduced water quality due to animal waste'
#  'Advice against bathing: pollution incident'
#  'Risk of reduced water quality due to sewage']

# %% [markdown]
# ### Distribution of SPM/TUR/CHL

# %%
risk = df2[['riskLevelLabel','SPM','TUR','CHL']]
risk
# Out:
#       riskLevelLabel        SPM        TUR        CHL
# 1             normal  25.661331  37.658855   9.443084
# 3             normal  16.239918  24.976324   9.984290
# 13            normal   8.327272  13.482300  12.682308
# 15         increased   9.625257  15.518951  12.746754
# 18            normal  10.335602  16.668087  11.645728
# ...              ...        ...        ...        ...
# 62595         normal   0.845388   1.444480   2.318278
# 62600         normal   0.843118   1.440889   2.294312
# 62607         normal   0.847636   1.448276   2.358512
# 62609         normal   0.845000   1.444237   2.366051
# 62612         normal   0.843170   1.441270   2.390961
#
# [5554 rows x 4 columns]

# %%
risk.max()
# Out:
# riskLevelLabel        normal
# SPM                508.77896
# TUR                 524.4528
# CHL               123.013695
# dtype: object

# %%
plt.figure(figsize=(16,4))
plt.hist(df2[['SPM','TUR','CHL']], 20)
plt.legend(['SPM','TUR','CHL'])
plt.show()

# %% [markdown]
# The majority of records with normal and increased risk have SPM, TUR, and CHL values within the range of (0, 100].

# %% [markdown]
# ### Hist of each risk level in SPM/TUR/CHL

# %% [markdown]
# Divide the values into intervals of 10s and group all values above 100 become a single intervel.

# %%
df_risk = risk[['riskLevelLabel','SPM','TUR','CHL']]
df_risk['SPM_Range'] = pd.cut(df_risk['SPM'], bins=np.arange(0, risk['SPM'].max()//100*100+101, 10))
df_risk['TUR_Range'] = pd.cut(df_risk['TUR'], bins=np.arange(0, risk['SPM'].max()//100*100+101, 10))
df_risk['CHL_Range'] = pd.cut(df_risk['CHL'], bins=np.arange(0, risk['SPM'].max()//100*100+101, 10))
df_risk = df_risk[['riskLevelLabel','SPM_Range','TUR_Range','CHL_Range']]
df_risk
# Out:
#       riskLevelLabel     SPM_Range     TUR_Range     CHL_Range
# 1             normal  (20.0, 30.0]  (30.0, 40.0]   (0.0, 10.0]
# 3             normal  (10.0, 20.0]  (20.0, 30.0]   (0.0, 10.0]
# 13            normal   (0.0, 10.0]  (10.0, 20.0]  (10.0, 20.0]
# 15         increased   (0.0, 10.0]  (10.0, 20.0]  (10.0, 20.0]
# 18            normal  (10.0, 20.0]  (10.0, 20.0]  (10.0, 20.0]
# ...              ...           ...           ...           ...
# 62595         normal   (0.0, 10.0]   (0.0, 10.0]   (0.0, 10.0]
# 62600         normal   (0.0, 10.0]   (0.0, 10.0]   (0.0, 10.0]
# 62607         normal   (0.0, 10.0]   (0.0, 10.0]   (0.0, 10.0]
# 62609         normal   (0.0, 10.0]   (0.0, 10.0]   (0.0, 10.0]
# 62612         normal   (0.0, 10.0]   (0.0, 10.0]   (0.0, 10.0]
#
# [5554 rows x 4 columns]

# %%
df_increased = df_risk[df_risk['riskLevelLabel'] == 'increased'].drop('riskLevelLabel',axis=1)
counts_increased = pd.DataFrame({
    'SPM': df_increased['SPM_Range'].value_counts(),
    'TUR': df_increased['TUR_Range'].value_counts(),
    'CHL': df_increased['CHL_Range'].value_counts(),
})

df_normal = df_risk[df_risk['riskLevelLabel'] == 'normal'].drop('riskLevelLabel',axis=1)
counts_normal = pd.DataFrame({
    'SPM': df_normal['SPM_Range'].value_counts(),
    'TUR': df_normal['TUR_Range'].value_counts(),
    'CHL': df_normal['CHL_Range'].value_counts(),
})

# %%
new_row = pd.DataFrame(counts_normal[10:].sum(axis=0)).T
counts_normal = pd.concat([counts_normal[:10], new_row])
counts_normal.index.values[-1] = '(100.0, 550,0]'

# %%
new_row = pd.DataFrame(counts_increased[10:].sum(axis=0)).T
counts_increased = pd.concat([counts_increased[:10], new_row])
counts_increased.index.values[-1] = '(100.0, 550,0]'

# %%
fig, axs = plt.subplots(2,1, figsize=(16, 8), sharex=True)

counts_increased.plot(kind='bar', ax=axs[0])
counts_normal.plot(kind='bar', ax=axs[1])
axs[1].set_xlabel('Value Range')
axs[0].set_ylabel(r'Count '+'\n'+'(increased risk)', rotation=0, ha='right')
axs[1].set_ylabel(r'Count '+'\n'+'(normal risk)', rotation=0, ha='right')
axs[0].legend(title='Column')
axs[1].legend(title='Column')
axs[1].set_xticklabels(axs[1].get_xticklabels(), rotation=70)
plt.tight_layout()
plt.show()
