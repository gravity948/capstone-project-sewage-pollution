# %%
import os
import pandas as pd
import re
import numpy as np
import netCDF4 as nc
from PIL import Image
import datetime 
import imageio
import os 
import matplotlib.pyplot as plt
import math
import xarray as xr

# %% [markdown]
# # Load NetCDF Data

# %%
# ds = nc.Dataset("cmems_obs_oc_nws_bgc_tur-spm-chl_nrt_l4-hr-mosaic_P1D-m_1678287603719.nc")
ds = nc.Dataset("cmems_obs_oc_nws_bgc_tur-spm-chl_nrt_l4-hr-mosaic_P1D-m_1677243373097.nc") # 31/10/2022 Dataset

# %%
for dim in ds.dimensions.values():
    print(dim)
# Out:
# <class 'netCDF4._netCDF4.Dimension'>: name = 'time', size = 1
# <class 'netCDF4._netCDF4.Dimension'>: name = 'lat', size = 11554
# <class 'netCDF4._netCDF4.Dimension'>: name = 'lon', size = 7377

# %%
# A significant number of non missing values! 
non_missing_vals = np.count_nonzero(~np.isnan(ds['CHL'][0, :, :].data))
print(f'Proportion of non missing values: {non_missing_vals}/{11554*7377}')
# Out:
# Proportion of non missing values: 3416902/85233858

# %%
ds = xr.open_dataset("cmems_obs_oc_nws_bgc_tur-spm-chl_nrt_l4-hr-mosaic_P1D-m_1677243373097.nc")
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 1, lat: 11554, lon: 7377)
# Coordinates:
#   * time     (time) datetime64[ns] 2022-10-31
#   * lat      (lat) float64 60.24 60.24 60.24 60.24 ... 49.55 49.55 49.55 49.54
#   * lon      (lon) float64 -10.8 -10.8 -10.8 -10.8 ... 2.076 2.078 2.08 2.082
# Data variables:
#     TUR      (time, lat, lon) float32 ...
#     SPM      (time, lat, lon) float32 ...
#     CHL      (time, lat, lon) float32 ...
# Attributes: (12/47)
#     TileSize:                   945:1192
#     id:                         20221031_P1D_CMEMS_HROC_L4_tur-spm-chl_NWS__1...
#     title:                      CMEMS HR-OC North West Shelf Region transpare...
#     region:                     NWS
#     tile:
#     cmems_product_id:           OCEANCOLOUR_NWS_BGC_HR_L4_NRT_009_209
#     ...                         ...
#     time_coverage_resolution:   P1D
#     platform:                   Sentinel-2
#     sensor:                     MSI
#     start_date:                 31-OCT-2022 00:00:00.000000
#     stop_date:                  31-OCT-2022 00:00:00.000000
#     History:                    Translated to CF-1.0 Conventions by Netcdf-Ja...

# %% [markdown]
# # Load Site Data

# %%
sites_df = pd.read_csv('site.csv')
sites = [[row['label'], row['lat'], row['long']] for index, row in sites_df.iterrows()]
sites[:10]
# Out:
# [['Seaton Carew North', 54.6646667372081, -1.18604276684644],
#  ['Seaton Carew Centre', 54.6599127717455, -1.18072760536662],
#  ['Seaton Carew North Gare', 54.6496298348782, -1.16466146681862],
#  ['Redcar Coatham', 54.6220674831445, -1.08159305534821],
#  ['Redcar Lifeboat Station', 54.620056404635, -1.06076199971504],
#  ['Redcar Granville', 54.6173480911732, -1.0522761465974],
#  ['Redcar Stray', 54.6055201971506, -1.03397313354301],
#  ['Marske Sands', 54.5999919286241, -1.01707668794072],
#  ['Saltburn', 54.5867919627395, -0.969779715531797],
#  ['Seaham Hall Beach', 54.8504496557177, -1.34149803443412]]

# %% [markdown]
# # Find NetCDF Data for each site

# %%
lats = ds['lat'][:].data
lons = ds['lon'][:].data

chls = []
turs = []
spms = []
for i in range(len(sites_df)):
    site = sites[i]
    site_name, lat, lon = site[0], site[1], site[2]
    lat_index = np.argmin(np.abs(lats - lat))
    lon_index = np.argmin(np.abs(lons - lon))
    
    chl = ds['CHL'][0, lat_index, lon_index].data
    tur = ds['TUR'][0, lat_index, lon_index].data
    spm = ds['SPM'][0, lat_index, lon_index].data
    
    chls.append(chl)
    turs.append(tur)
    spms.append(spm)
    
chls
# Out:
# [array(6.832733, dtype=float32),
#  array(7.872392, dtype=float32),
#  array(7.2874975, dtype=float32),
#  array(5.980059, dtype=float32),
#  array(7.0469513, dtype=float32),
#  array(nan, dtype=float32),
#  array(6.655414, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(6.8772583, dtype=float32),
#  array(7.874783, dtype=float32),
#  array(12.485974, dtype=float32),
#  array(5.049927, dtype=float32),
#  array(5.8652043, dtype=float32),
#  array(7.8544593, dtype=float32),
#  array(5.2067327, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(15.65057, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(5.7757297, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(5.93999, dtype=float32),
#  array(4.498989, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(6.492484, dtype=float32),
#  array(6.5908766, dtype=float32),
#  array(5.2622213, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(6.9031987, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(8.309269, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(26.995813, dtype=float32),
#  array(nan, dtype=float32),
#  array(5.6783323, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(8.095415, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(15.064616, dtype=float32),
#  array(5.7867537, dtype=float32),
#  array(8.438866, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(1.8915366, dtype=float32),
#  array(4.65703, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(1.8302904, dtype=float32),
#  array(nan, dtype=float32),
#  array(15.105993, dtype=float32),
#  array(6.80038, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(6.4809203, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(7.114358, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(8.530067, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(1.8302904, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(1.9971894, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(5.5644393, dtype=float32),
#  array(nan, dtype=float32),
#  array(1.8302904, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(5.636971, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(13.685613, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(7.186965, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(4.877456, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(5.4004784, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(1.8302904, dtype=float32),
#  array(1.8302904, dtype=float32),
#  array(nan, dtype=float32),
#  array(3.2373426, dtype=float32),
#  array(nan, dtype=float32),
#  array(7.5230627, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(5.631192, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(1.5150975, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(10.60895, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(4.0968494, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(11.22969, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32),
#  array(nan, dtype=float32)]

# %%
# Number of missing values
chls = pd.Series(chls)
turs = pd.Series(turs)
spms = pd.Series(spms)

print(f'Missing values for CHLs: {len(chls[chls==0])}/430')
print(f'Missing values for TURs: {len(turs[turs==0])}/430')
print(f'Missing values for SPMs: {len(spms[spms==0])}/430')
# Out:
# Missing values for CHLs: 0/430
# Missing values for TURs: 0/430
# Missing values for SPMs: 0/430

# %% [markdown]
# # Making local plots

# %%
# General Function
def site_local_plot(ds, site_name, variable, dimension = 10):
    '''
    ds: .nc file, dataset for a single day of data
    site_name: one of the 430 site names
    variable: 'CHL', 'TUR', 'SPM'
    dimension: creates dimension*2+1 square plot.
    '''
    lat = float(sites_df[sites_df['label'] == site_name]['lat'])
    lon = float(sites_df[sites_df['label'] == site_name]['long'])
    
    lats = ds['lat'][:].data
    lons = ds['lon'][:].data
    
    lat_index = np.argmin(np.abs(lats - lat))
    lon_index = np.argmin(np.abs(lons - lon))
    
    i = dimension
    arr = ds[f'{variable}'][0,lat_index-i:lat_index+i+1,lon_index-i:lon_index+i+1].data
    
    plt.imshow(arr, cmap='viridis', interpolation='nearest')
    
    # Add highlighted point of Site Location
    plt.scatter(i, i, s=100, marker='o', facecolors='r')
    
    # Plot colorbar
    plt.colorbar()
    
    # Changing Ticks to match latitude and longitude
    new_xticks = [round(lons[j], 3) for j in np.arange(lon_index-i, lon_index+i+1)][::5]
    plt.xticks(range(len(new_xticks)*5)[::5], new_xticks)
    new_yticks = [round(lats[j], 3) for j in np.arange(lat_index-i, lat_index+i+1)][::5]
    plt.yticks(range(len(new_yticks)*5)[::5], new_yticks)
    
    # Add Title
    plt.title(f'{site_name}, {variable}')
    
    # Change Background colour to black
    plt.rcParams['axes.facecolor'] = 'black'

# %%
site = sites_df['label'][0]
site_local_plot(ds, site, 'CHL', 5)

# %% [markdown]
# ### All 430 Sites, 31/10/2022

# %%
# %%time
fig, axs = plt.subplots(nrows=108, ncols=4, figsize=(25, 500))
site_names = sites_df['label']

for i, ax in enumerate(axs.flatten()):
    if i < 430:
        site_local_plot(site_names[i], 'CHL', 5)
        plt.sca(ax)
        plt.xticks([])
        plt.yticks([])
        ax.set_facecolor('black')
    else:
        ax.axis('off')
        
plt.subplots_adjust(wspace=0.2, hspace=0.6)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File <timed exec>:6
#
# Cell In[9], line 9, in site_local_plot(ds, site_name, variable, dimension)
#       2 def site_local_plot(ds, site_name, variable, dimension = 10):
#       3     '''
#       4     ds: .nc file, dataset for a single day of data
#       5     site_name: one of the 430 site names
#       6     variable: 'CHL', 'TUR', 'SPM'
#       7     dimension: creates dimension*2+1 square plot.
#       8     '''
# ----> 9     lat = float(sites_df[sites_df['label'] == site_name]['lat'])
#      10     lon = float(sites_df[sites_df['label'] == site_name]['long'])
#      12     lats = ds['lat'][:].data
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/core/series.py:206, in _coerce_method.<locals>.wrapper(self)
#     204 if len(self) == 1:
#     205     return converter(self.iloc[0])
# --> 206 raise TypeError(f"cannot convert the series to {converter}")
#
# TypeError: cannot convert the series to <class 'float'>

# %% [markdown]
# ### Comparing Across Two Dates

# %%
# uncomment below to install motuclient 
# !python -m pip install motuclient==1.8.4 --no-cache-dir

# %%
# Downloading data from 30/06/2022
import os

username = "slai"
password = "Capstone2023"
output_directory = "/Users/SallyLai/Desktop/LSE/Masters/Capstone/capstone-project-sewage-pollution"
output_filename = "20220630.nc"
product_id = "OCEANCOLOUR_NWS_BGC_HR_L4_NRT_009_209-TDS"
dataset_id = "cmems_obs_oc_nws_bgc_tur-spm-chl_nrt_l4-hr-mosaic_P1D-m"

query = ('python -m motuclient --motu https://nrt.cmems-du.eu/motu-web/Motu --service-id ' + product_id + ' --product-id ' + dataset_id + 
         ' --longitude-min -11 --longitude-max 2 --latitude-min 49 --latitude-max 60 ' +
         '--date-min "2022-06-30 00:00:00" --date-max "2022-06-30 23:59:59" ' +
         '--variable CHL --variable SPM --variable TUR ' +
         '--out-dir ' + output_directory + ' --out-name ' + output_filename +
         ' --user ' + username + ' --pwd ' + password)

os.system(query)
# Out:
# 2023-03-10 15:27:30.396 [ INFO] Asynchronous mode set
# 2023-03-10 15:27:30.397 [ INFO] Authenticating user slai for service https://nrt.cmems-du.eu/motu-web/Motu
# 2023-03-10 15:27:31.289 [ INFO] Requesting file to download (this can take a while)...
# 2023-03-10 15:27:36.896 [ INFO] Authenticating user slai for service https://nrt.cmems-du.eu/motu-web/Motu
# 2023-03-10 15:27:44.197 [ INFO] Product is not yet available (request in progress)
# 2023-03-10 15:27:54.202 [ INFO] Authenticating user slai for service https://nrt.cmems-du.eu/motu-web/Motu
# 2023-03-10 15:28:00.707 [ INFO] The product is ready for download
# 2023-03-10 15:28:00.708 [ INFO] Downloading file (this can take a while)...
# 2023-03-10 15:28:01.034 [ INFO] File type: application/x-netcdf
# 2023-03-10 15:28:01.035 [ INFO] File size: 1.1 GB (1061269504 B)
# 2023-03-10 15:28:01.035 [ INFO] Downloading file /Users/SallyLai/Desktop/LSE/Masters/Capstone/capstone-project-sewage-pollution/20220630.nc
# 2023-03-10 15:28:03.026 [ INFO] -   1.1 GB (1.0%)
# 2023-03-10 15:28:04.778 [ INFO] -   1.1 GB (2.0%)
# 2023-03-10 15:28:06.182 [ INFO] -   1.1 GB (3.0%)
# 2023-03-10 15:28:07.579 [ INFO] -   1.1 GB (4.0%)
# 2023-03-10 15:28:09.220 [ INFO] -   1.1 GB (5.0%)
# 2023-03-10 15:28:10.623 [ INFO] -   1.1 GB (6.0%)
# 2023-03-10 15:28:12.060 [ INFO] -   1.1 GB (7.0%)
# 2023-03-10 15:28:13.481 [ INFO] -   1.1 GB (8.0%)
# 2023-03-10 15:28:14.833 [ INFO] -   1.1 GB (9.0%)
# 2023-03-10 15:28:16.542 [ INFO] -   1.1 GB (10.0%)
# 2023-03-10 15:28:18.920 [ INFO] -   1.1 GB (11.0%)
# 2023-03-10 15:28:20.436 [ INFO] -   1.1 GB (12.0%)
# 2023-03-10 15:28:22.150 [ INFO] -   1.1 GB (13.0%)
# 2023-03-10 15:28:23.944 [ INFO] -   1.1 GB (14.0%)
# 2023-03-10 15:28:25.583 [ INFO] -   1.1 GB (15.0%)
# 2023-03-10 15:28:27.843 [ INFO] -   1.1 GB (16.0%)
# 2023-03-10 15:28:29.251 [ INFO] -   1.1 GB (17.0%)
# 2023-03-10 15:28:30.961 [ INFO] -   1.1 GB (18.0%)
# 2023-03-10 15:28:32.598 [ INFO] -   1.1 GB (19.0%)
# 2023-03-10 15:28:34.363 [ INFO] -   1.1 GB (20.0%)
# 2023-03-10 15:28:36.698 [ INFO] -   1.1 GB (21.0%)
# 2023-03-10 15:28:38.771 [ INFO] -   1.1 GB (22.0%)
# 2023-03-10 15:28:40.400 [ INFO] -   1.1 GB (23.0%)
# 2023-03-10 15:28:42.070 [ INFO] -   1.1 GB (24.0%)
# 2023-03-10 15:28:43.694 [ INFO] -   1.1 GB (25.0%)
# 2023-03-10 15:28:45.247 [ INFO] -   1.1 GB (26.0%)
# 2023-03-10 15:28:46.766 [ INFO] -   1.1 GB (27.0%)
# 2023-03-10 15:28:48.206 [ INFO] -   1.1 GB (28.0%)
# 2023-03-10 15:28:49.862 [ INFO] -   1.1 GB (29.0%)
# 2023-03-10 15:28:52.331 [ INFO] -   1.1 GB (30.0%)
# 2023-03-10 15:28:53.960 [ INFO] -   1.1 GB (31.0%)
# 2023-03-10 15:28:55.465 [ INFO] -   1.1 GB (32.0%)

# %%
june_thirty = xr.open_dataset("20220630.nc")
june_thirty

# %%
# Function to Calculate Comparison 
def comparison_plot(ds1, ds2, site_name, variable, dimension = 5):
    '''
    Assumes that lat_index and lon_index snaps the lat and lon point to the same grid across datasets
    '''
    lat = float(sites_df[sites_df['label'] == site_name]['lat'])
    lon = float(sites_df[sites_df['label'] == site_name]['long'])
    
    # First dataset
    lats = ds1['lat'][:].data
    lons = ds1['lon'][:].data
    
    lat_index = np.argmin(np.abs(lats - lat))
    lon_index = np.argmin(np.abs(lons - lon))
    
    i = dimension
    arr1 = ds1[f'{variable}'][0,lat_index-i:lat_index+i+1,lon_index-i:lon_index+i+1].data
    
    # Second dataset
    lats = ds2['lat'][:].data
    lons = ds2['lon'][:].data
    
    lat_index = np.argmin(np.abs(lats - lat))
    lon_index = np.argmin(np.abs(lons - lon))
    
    i = dimension
    arr2 = ds2[f'{variable}'][0,lat_index-i:lat_index+i+1,lon_index-i:lon_index+i+1].data
    
    # Mask for when the arrays have the same values
    mask_same = np.logical_xor(np.isnan(arr1), np.isnan(arr2))
    mask_same = np.logical_not(mask_same)
    
    # Mask for when the arrays have the same values
    mask_same = np.logical_xor(np.isnan(arr1), np.isnan(arr2))
    mask_same = np.logical_not(mask_same)

    # Plot
    plt.imshow(mask_same, cmap='Set1')
    
    # Colorbar
    plt.colorbar()

    # Changing Ticks to match latitude and longitude
    new_xticks = [round(lons[j], 3) for j in np.arange(lon_index-i, lon_index+i+1)][::5]
    plt.xticks(range(len(new_xticks)*5)[::5], new_xticks)
    new_yticks = [round(lats[j], 3) for j in np.arange(lat_index-i, lat_index+i+1)][::5]
    plt.yticks(range(len(new_yticks)*5)[::5], new_yticks)

    # Add Title
    plt.title(f'{site_name}, {variable}')

# %%
site = sites_df['label'][2]
comparison_plot(ds, june_thirty, site, 'CHL', 5)

# %%
# %%time
fig, axs = plt.subplots(nrows=108, ncols=4, figsize=(25, 500))
site_names = sites_df['label']

for i, ax in enumerate(axs.flatten()):
    if i < 430:
        comparison_plot(ds, june, site_names[i], 'CHL', 5)
        plt.sca(ax)
        plt.xticks([])
        plt.yticks([])
        ax.set_facecolor('black')
    else:
        ax.axis('off')
        
plt.subplots_adjust(wspace=0.2, hspace=0.6)
plt.show()

# %%
# Plot for 30/06/2022
site_local_plot(june_thirty, 'Allonby South', 'CHL', 5)

# %%
# Plot for 31/10/2022
site_local_plot(ds, 'Allonby South', 'CHL', 5)

# %%
# File Size Download Limit of 2048Mb / 2.048 Gb
# Max Download 2 days at a time
# import os

# username = "slai"
# password = "Capstone2023"
# output_directory = "/Users/SallyLai/Desktop/LSE/Masters/Capstone/capstone-project-sewage-pollution/copernicus_code"
# output_filename = "20220301_02.nc"
# product_id = "OCEANCOLOUR_NWS_BGC_HR_L4_NRT_009_209-TDS"
# dataset_id = "cmems_obs_oc_nws_bgc_tur-spm-chl_nrt_l4-hr-mosaic_P1D-m"

# query = ('python -m motuclient --motu https://nrt.cmems-du.eu/motu-web/Motu --service-id ' + product_id + ' --product-id ' + dataset_id + 
#          ' --longitude-min -11 --longitude-max 2 --latitude-min 49 --latitude-max 60 ' +
#          '--date-min "2022-03-01 00:00:00" --date-max "2022-03-02 23:59:59" ' +
#          '--variable CHL --variable SPM --variable TUR ' +
#          '--out-dir ' + output_directory + ' --out-name ' + output_filename +
#          ' --user ' + username + ' --pwd ' + password)

# os.system(query)

# %% [markdown]
# ## Comparing Across 6 days

# %%
first = nc.Dataset("20220301_02.nc")
second = nc.Dataset("20220303_04.nc")
third = nc.Dataset("20220305_06.nc")

# %%
print(np.count_nonzero(~np.isnan(first['CHL'][0, :, :].data)))
print(np.count_nonzero(~np.isnan(first['CHL'][1, :, :].data)))
print(np.count_nonzero(~np.isnan(second['CHL'][0, :, :].data)))
print(np.count_nonzero(~np.isnan(second['CHL'][1, :, :].data)))
print(np.count_nonzero(~np.isnan(third['CHL'][0, :, :].data)))
print(np.count_nonzero(~np.isnan(third['CHL'][1, :, :].data)))

# %%
def comparison_plot_multiple_days(ds1, ds2, ds3, site_name, variable, dimension = 5):
    
    lat = float(sites_df[sites_df['label'] == site_name]['lat'])
    lon = float(sites_df[sites_df['label'] == site_name]['long'])
    
    lats = ds1['lat'][:].data
    lons = ds1['lon'][:].data
    lat_index = np.argmin(np.abs(lats - lat))
    lon_index = np.argmin(np.abs(lons - lon))
    i = dimension
    
    arr1 = ds1[f'{variable}'][0,lat_index-i:lat_index+i+1,lon_index-i:lon_index+i+1].data
    arr2 = ds1[f'{variable}'][1,lat_index-i:lat_index+i+1,lon_index-i:lon_index+i+1].data
    arr3 = ds2[f'{variable}'][0,lat_index-i:lat_index+i+1,lon_index-i:lon_index+i+1].data
    arr4 = ds2[f'{variable}'][1,lat_index-i:lat_index+i+1,lon_index-i:lon_index+i+1].data
    arr5 = ds3[f'{variable}'][0,lat_index-i:lat_index+i+1,lon_index-i:lon_index+i+1].data
    arr6 = ds3[f'{variable}'][1,lat_index-i:lat_index+i+1,lon_index-i:lon_index+i+1].data
    
    arr_list = [arr1, arr2, arr3, arr4, arr5, arr6]
    
    arr_list_binary = []
    for arr in arr_list: 
        missing_values = np.isnan(arr)
        arr[missing_values] = 0
        arr[~missing_values] = 1
        arr_list_binary.append(arr)
        
    arr_sum = np.sum(arr_list_binary, axis=0)
        
     # Plot
    plt.imshow(arr_sum, cmap='Set1')
    
    # Colorbar
    plt.colorbar()

    # Changing Ticks to match latitude and longitude
    new_xticks = [round(lons[j], 3) for j in np.arange(lon_index-i, lon_index+i+1)][::5]
    plt.xticks(range(len(new_xticks)*5)[::5], new_xticks)
    new_yticks = [round(lats[j], 3) for j in np.arange(lat_index-i, lat_index+i+1)][::5]
    plt.yticks(range(len(new_yticks)*5)[::5], new_yticks)

    # Add Title
    plt.title(f'{site_name}, {variable}')

# %%
comparison_plot_multiple_days(first, second, third, 'Seaton Carew North Gare', 'CHL')

# %%
fig, axs = plt.subplots(nrows=108, ncols=4, figsize=(25, 500))
site_names = sites_df['label']

for i, ax in enumerate(axs.flatten()):
    if i < 430:
        comparison_plot_multiple_days(first, second, third, site_names[i], 'CHL', 5)
        plt.sca(ax)
        plt.xticks([])
        plt.yticks([])
        ax.set_facecolor('black')
    else:
        ax.axis('off')
        
plt.subplots_adjust(wspace=0.2, hspace=0.6)
plt.show()

# %%
# Collecting Data

username = "slai"
password = "Capstone2023"
product_id = "OCEANCOLOUR_NWS_BGC_HR_L4_NRT_009_209-TDS"
dataset_id = "cmems_obs_oc_nws_bgc_tur-spm-chl_nrt_l4-hr-mosaic_P1D-m"

# Change the following
output_directory = "/Users/SallyLai/Desktop/LSE/Masters/Capstone/capstone-project-sewage-pollution/copernicus_code"
start = '05'
end = '06'
output_filename = f"202203{start}_{end}.nc"

    
query = ('python -m motuclient --motu https://nrt.cmems-du.eu/motu-web/Motu --service-id ' + product_id + ' --product-id ' + dataset_id + 
         ' --longitude-min -11 --longitude-max 2 --latitude-min 49 --latitude-max 60 ' +
         f'--date-min "2022-03-{start} 00:00:00" --date-max "2022-03-{end} 23:59:59" ' +
         '--variable CHL --variable SPM --variable TUR ' +
         '--out-dir ' + output_directory + ' --out-name ' + output_filename +
         ' --user ' + username + ' --pwd ' + password)

os.system(query)

# %% [markdown]
# # Big Plot

# %%
# conda install -c conda-forge cartopy

# %%
arr = ds['CHL'][0, :, :].data

# Create a mask array
mask = np.isnan(arr)

fig = plt.figure(figsize=(40, 40))

# Plot the numpy array as an image
plt.imshow(arr, cmap='jet')

# Plot the mask array on top of the numpy array
# plt.imshow(mask, cmap='gray', alpha=0.3)

# Add a colorbar
cbar = plt.colorbar()
cbar.set_label('Value')

# Change ticks
plt.xticks(lons)
plt.yticks(lats)
# plt.xlim(lons[0], lons[-1])
# plt.ylim(lats[0], lats[-1])

# Show the plot
plt.show()

# %%
# !conda install cartopy --yes

# %%
# !pip uninstall lxml
# !ARCHFLAGS="-arch arm64" pip install lxml --compile --no-cache-dir

# %%
# zsd = ds['CHL'][0,:,:].data
# zsd

# %%
# arr = zsd

# # Create a mask array
# mask = np.isnan(arr)

# # Create a map with the appropriate projection
# ax = plt.axes(projection=ccrs.PlateCarree())

# # Plot the numpy array as an image
# im = ax.imshow(arr, cmap='jet', transform=ccrs.PlateCarree())

# # Plot the mask array on top of the numpy array
# ax.imshow(mask, cmap='gray', alpha=0.3, transform=ccrs.PlateCarree())

# # Add a colorbar
# cbar = plt.colorbar(im, ax=ax, fraction=0.025, pad=0.04)
# cbar.set_label('Value')

# # Add map features
# ax.coastlines()
# ax.gridlines()

# # Show the plot
# plt.show()

# %%
# !pip3 install cartopy

# %%
# import matplotlib
# # import cartopy

# print('Matplotlib version:', matplotlib.__version__)
# print('Cartopy version:', cartopy.__version__)

# %%
# from platform import python_version

# print(python_version())

# %%
# !pip install --upgrade matplotlib

# %%
# zsd = ds['CHL'][0,:,:].data

# plt.imshow(zsd, cmap='hot', interpolation='nearest');

# %%
# zsd.shape

# %%
# from matplotlib import cm

# zsd = ds['CHL'][0,:,:].data


# # (n_snapshots, w, h) = ds['CHL'][:,:,:].data.shape
# # date = datetime.date(1900, 1, 1) + datetime.timedelta(days=int(ds['time'][0].data))

# #img = Image.fromarray(np.where(-999, 0, zsd))
# # arr = (255 - np.where(zsd == -999, 0, zsd) / zsd.max() * 255).astype(np.uint8)
# # arr = (255 - np.where(zsd == -999, 0, zsd) / zsd.max() * 255).astype(np.uint8)
# arr = (255 - np.where(zsd == -999, 0, zsd) / zsd.max() * 255).astype(np.uint8)

# # img = Image.fromarray(cm.viridis(arr),mode='L')

# # plt.imsave('test.png', arr, cmap='viridis')
# img = Image.fromarray(arr,mode='L').convert('RGB')
# # img = img.resize((700, 700))
# img
