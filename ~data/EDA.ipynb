# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cope = pd.read_csv('Datasets/copernicus_data_nrt_l4.csv')
cope = cope[["site","time","SPM","TUR","CHL"]]
cope
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 cope = pd.read_csv('Datasets/copernicus_data_nrt_l4.csv')
#       2 cope = cope[["site","time","SPM","TUR","CHL"]]
#       3 cope
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
# ...

# %%
df = pd.read_csv('feature_extraction.csv')
df
# Out:
#               time                    site  TUR_1x1_median  SPM_1x1_median  \
# 0       2022-03-01                Ainsdale             NaN             NaN
# 1       2022-03-01                 Allonby             NaN             NaN
# 2       2022-03-01           Allonby_South             NaN             NaN
# 3       2022-03-01             Amble_Links             NaN             NaN
# 4       2022-03-01                 Anderby             NaN             NaN
# ...            ...                     ...             ...             ...
# 101905  2022-10-31              Withernsea             NaN             NaN
# 101906  2022-10-31  Wolvercote_Mill_Stream             NaN             NaN
# 101907  2022-10-31      Woolacombe_Village             NaN             NaN
# 101908  2022-10-31                Worthing             NaN             NaN
# 101909  2022-10-31               Yaverland             NaN             NaN
#
# ...

# %%
print(df.shape)
print(df.isnull().sum())
# Out:
# (101910, 74)
# time                  0
# site                  0
# TUR_1x1_median    93422
# SPM_1x1_median    93422
# CHL_1x1_median    93422
#                   ...
# SPM_11x11_q1      73430
# CHL_11x11_q1      73430
# TUR_11x11_q3      73430
# SPM_11x11_q3      73430
# CHL_11x11_q3      73430
# Length: 74, dtype: int64

# %%
df.columns
# Out:
# Index(['time', 'site', 'TUR_1x1_median', 'SPM_1x1_median', 'CHL_1x1_median',
#        'TUR_1x1_mean', 'SPM_1x1_mean', 'CHL_1x1_mean', 'TUR_1x1_q1',
#        'SPM_1x1_q1', 'CHL_1x1_q1', 'TUR_1x1_q3', 'SPM_1x1_q3', 'CHL_1x1_q3',
#        'TUR_3x3_median', 'SPM_3x3_median', 'CHL_3x3_median', 'TUR_3x3_mean',
#        'SPM_3x3_mean', 'CHL_3x3_mean', 'TUR_3x3_q1', 'SPM_3x3_q1',
#        'CHL_3x3_q1', 'TUR_3x3_q3', 'SPM_3x3_q3', 'CHL_3x3_q3',
#        'TUR_5x5_median', 'SPM_5x5_median', 'CHL_5x5_median', 'TUR_5x5_mean',
#        'SPM_5x5_mean', 'CHL_5x5_mean', 'TUR_5x5_q1', 'SPM_5x5_q1',
#        'CHL_5x5_q1', 'TUR_5x5_q3', 'SPM_5x5_q3', 'CHL_5x5_q3',
#        'TUR_7x7_median', 'SPM_7x7_median', 'CHL_7x7_median', 'TUR_7x7_mean',
#        'SPM_7x7_mean', 'CHL_7x7_mean', 'TUR_7x7_q1', 'SPM_7x7_q1',
#        'CHL_7x7_q1', 'TUR_7x7_q3', 'SPM_7x7_q3', 'CHL_7x7_q3',
#        'TUR_9x9_median', 'SPM_9x9_median', 'CHL_9x9_median', 'TUR_9x9_mean',
# ...

# %%
for i in list(range(2,72,3)):
    print(df.columns[i:i+3])
# Out:
# Index(['TUR_1x1_median', 'SPM_1x1_median', 'CHL_1x1_median'], dtype='object')
# Index(['TUR_1x1_mean', 'SPM_1x1_mean', 'CHL_1x1_mean'], dtype='object')
# Index(['TUR_1x1_q1', 'SPM_1x1_q1', 'CHL_1x1_q1'], dtype='object')
# Index(['TUR_1x1_q3', 'SPM_1x1_q3', 'CHL_1x1_q3'], dtype='object')
# Index(['TUR_3x3_median', 'SPM_3x3_median', 'CHL_3x3_median'], dtype='object')
# Index(['TUR_3x3_mean', 'SPM_3x3_mean', 'CHL_3x3_mean'], dtype='object')
# Index(['TUR_3x3_q1', 'SPM_3x3_q1', 'CHL_3x3_q1'], dtype='object')
# Index(['TUR_3x3_q3', 'SPM_3x3_q3', 'CHL_3x3_q3'], dtype='object')
# Index(['TUR_5x5_median', 'SPM_5x5_median', 'CHL_5x5_median'], dtype='object')
# Index(['TUR_5x5_mean', 'SPM_5x5_mean', 'CHL_5x5_mean'], dtype='object')
# Index(['TUR_5x5_q1', 'SPM_5x5_q1', 'CHL_5x5_q1'], dtype='object')
# Index(['TUR_5x5_q3', 'SPM_5x5_q3', 'CHL_5x5_q3'], dtype='object')
# Index(['TUR_7x7_median', 'SPM_7x7_median', 'CHL_7x7_median'], dtype='object')
# ...

# %%
df_11x11_mean = df.iloc[:, :2].join(df.iloc[:, -9:-6])
df_11x11_mean
# Out:
#               time                    site  TUR_11x11_mean  SPM_11x11_mean  \
# 0       2022-03-01                Ainsdale             NaN             NaN
# 1       2022-03-01                 Allonby             NaN             NaN
# 2       2022-03-01           Allonby_South             NaN             NaN
# 3       2022-03-01             Amble_Links             NaN             NaN
# 4       2022-03-01                 Anderby             NaN             NaN
# ...            ...                     ...             ...             ...
# 101905  2022-10-31              Withernsea             NaN             NaN
# 101906  2022-10-31  Wolvercote_Mill_Stream             NaN             NaN
# 101907  2022-10-31      Woolacombe_Village       34.662595       25.860545
# 101908  2022-10-31                Worthing             NaN             NaN
# 101909  2022-10-31               Yaverland             NaN             NaN
#
#         CHL_11x11_mean
# 0                  NaN
# ...

# %%
print(df_11x11_mean.shape)
print(df_11x11_mean.isnull().sum())
# Out:
# (101910, 5)
# time                  0
# site                  0
# TUR_11x11_mean    73430
# SPM_11x11_mean    73430
# CHL_11x11_mean    73430
# dtype: int64

# %%
df1 = pd.merge(df_11x11_mean, cope, on=['site','time'])
df1 = df.dropna()
df1 = df.rename({'intestinalEnterococciCount': 'IE_count', 'escherichiaColiCount': 'EC_count'}, axis=1)  # new method
df1
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[39], line 5
#       1 fig, ax = plt.subplots(figsize=(18, 16))
#       3 for site, group in df_11x11_median.groupby('site'):
#       4     # plot the data for each group using a different color
# ----> 5     plt.scatter(group['time'], group['site'], c=group['TUR_11x11_median'], cmap='Reds', label='TUR_11x11_median')
#       6     plt.scatter(group['time'], group['site'], c=group['SPM_11x11_median'], cmap='Blues', label='SPM_11x11_median')
#       7     plt.scatter(group['time'], group['site'], c=group['CHL_11x11_median'], cmap='Greens', label='CHL_11x11_median')
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/pyplot.py:2862, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    2857 @_copy_docstring_and_deprecators(Axes.scatter)
# ...
