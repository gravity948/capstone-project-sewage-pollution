# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import pearsonr, t

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
sample = pd.read_csv('~data/samples.csv')
sample = sample[["label","sampleTime","intestinalEnterococciCount","escherichiaColiCount"]]
sample['sampleTime'] = sample['sampleTime'].str[:10]
sample = sample.rename(columns={'label': 'site', 'sampleTime': 'time'})
sample
# Out:
#                     site        time  intestinalEnterococciCount  \
# 0     Seaton Carew North  2022-05-06                          18
# 1     Seaton Carew North  2022-05-19                          45
# 2     Seaton Carew North  2022-05-25                         130
# 3     Seaton Carew North  2022-05-31                          10
# 4     Seaton Carew North  2022-06-08                         250
# ...                  ...         ...                         ...
# 7204        Westward Ho!  2022-08-18                          10
# 7205        Westward Ho!  2022-08-25                          10
# 7206        Westward Ho!  2022-09-08                          64
# 7207        Westward Ho!  2022-09-13                          10
# 7208        Westward Ho!  2022-09-22                          10
#
#       escherichiaColiCount
# 0                       10
# 1                       10
# 2                      310
# 3                       10
# 4                      270
# ...                    ...
# 7204                    10
# 7205                    10
# 7206                    45
# 7207                    10
# 7208                    10
#
# [7209 rows x 4 columns]

# %%
riskforecasting = pd.read_csv('~data/pollution_risk_forecasting.csv')
riskforecasting = riskforecasting[['label','predictedAt','warning','riskLevelLabel']]
riskforecasting['predictedAt'] = pd.to_datetime(riskforecasting.predictedAt).dt.strftime('%Y-%m-%d')
riskforecasting = riskforecasting.rename(columns={'label': 'site', 'predictedAt': 'time'})
riskforecasting
# Out:
#                      site        time  \
# 0      Seaton Carew North  2022-04-28
# 1      Seaton Carew North  2022-04-29
# 2      Seaton Carew North  2022-04-30
# 3      Seaton Carew North  2022-05-04
# 4      Seaton Carew North  2022-05-05
# ...                   ...         ...
# 63641        Westward Ho!  2022-09-26
# 63642        Westward Ho!  2022-09-27
# 63643        Westward Ho!  2022-09-28
# 63644        Westward Ho!  2022-09-29
# 63645        Westward Ho!  2022-09-30
#
#                                         warning riskLevelLabel
# 0      Pollution RIsk Forecasts will start soon         normal
# 1      Pollution RIsk Forecasts will start soon         normal
# 2      Pollution RIsk Forecasts will start soon         normal
# 3                          No warnings in place         normal
# 4                          No warnings in place         normal
# ...                                         ...            ...
# 63641           No pollution incidents reported         normal
# 63642           No pollution incidents reported         normal
# 63643           No pollution incidents reported         normal
# 63644           No pollution incidents reported         normal
# 63645           No pollution incidents reported         normal
#
# [63646 rows x 4 columns]

# %%
feature = pd.read_csv('~data/feature_extraction.csv')
feature
# Out:
#               time                    site  TUR_1x1_median  SPM_1x1_median  \
# 0       2022-03-01                Ainsdale             NaN             NaN
# 1       2022-03-01                 Allonby             NaN             NaN
# 2       2022-03-01           Allonby_South             NaN             NaN
# 3       2022-03-01             Amble_Links             NaN             NaN
# 4       2022-03-01                 Anderby             NaN             NaN
# ...            ...                     ...             ...             ...
# 101905  2022-10-31              Withernsea             NaN             NaN
# 101906  2022-10-31  Wolvercote_Mill_Stream             NaN             NaN
# 101907  2022-10-31      Woolacombe_Village             NaN             NaN
# 101908  2022-10-31                Worthing             NaN             NaN
# 101909  2022-10-31               Yaverland             NaN             NaN
#
#         CHL_1x1_median  TUR_1x1_mean  SPM_1x1_mean  CHL_1x1_mean  TUR_1x1_q1  \
# 0                  NaN           NaN           NaN           NaN         NaN
# 1                  NaN           NaN           NaN           NaN         NaN
# 2                  NaN           NaN           NaN           NaN         NaN
# 3                  NaN           NaN           NaN           NaN         NaN
# 4                  NaN           NaN           NaN           NaN         NaN
# ...                ...           ...           ...           ...         ...
# 101905             NaN           NaN           NaN           NaN         NaN
# 101906             NaN           NaN           NaN           NaN         NaN
# 101907             NaN           NaN           NaN           NaN         NaN
# 101908             NaN           NaN           NaN           NaN         NaN
# 101909             NaN           NaN           NaN           NaN         NaN
#
#         SPM_1x1_q1  ...  CHL_11x11_median  TUR_11x11_mean  SPM_11x11_mean  \
# 0              NaN  ...               NaN             NaN             NaN
# 1              NaN  ...               NaN             NaN             NaN
# 2              NaN  ...               NaN             NaN             NaN
# 3              NaN  ...               NaN             NaN             NaN
# 4              NaN  ...               NaN             NaN             NaN
# ...            ...  ...               ...             ...             ...
# 101905         NaN  ...               NaN             NaN             NaN
# 101906         NaN  ...               NaN             NaN             NaN
# 101907         NaN  ...          6.883528       34.662595       25.860545
# 101908         NaN  ...               NaN             NaN             NaN
# 101909         NaN  ...               NaN             NaN             NaN
#
#         CHL_11x11_mean  TUR_11x11_q1  SPM_11x11_q1  CHL_11x11_q1  \
# 0                  NaN           NaN           NaN           NaN
# 1                  NaN           NaN           NaN           NaN
# 2                  NaN           NaN           NaN           NaN
# 3                  NaN           NaN           NaN           NaN
# 4                  NaN           NaN           NaN           NaN
# ...                ...           ...           ...           ...
# 101905             NaN           NaN           NaN           NaN
# 101906             NaN           NaN           NaN           NaN
# 101907        6.887635      5.332965      3.172126      6.447352
# 101908             NaN           NaN           NaN           NaN
# 101909             NaN           NaN           NaN           NaN
#
#         TUR_11x11_q3  SPM_11x11_q3  CHL_11x11_q3
# 0                NaN           NaN           NaN
# 1                NaN           NaN           NaN
# 2                NaN           NaN           NaN
# 3                NaN           NaN           NaN
# 4                NaN           NaN           NaN
# ...              ...           ...           ...
# 101905           NaN           NaN           NaN
# 101906           NaN           NaN           NaN
# 101907     62.290684     43.051556      7.345246
# 101908           NaN           NaN           NaN
# 101909           NaN           NaN           NaN
#
# [101910 rows x 74 columns]

# %%
print(feature.shape)
print(feature.isnull().sum())
# Out:
# (101910, 74)
# time                  0
# site                  0
# TUR_1x1_median    93422
# SPM_1x1_median    93422
# CHL_1x1_median    93422
#                   ...
# SPM_11x11_q1      73430
# CHL_11x11_q1      73430
# TUR_11x11_q3      73430
# SPM_11x11_q3      73430
# CHL_11x11_q3      73430
# Length: 74, dtype: int64

# %% [markdown]
# # Comparing values of all pixels from 1x1 to 11x11

# %%
TUR_df = feature.filter(regex='^TUR').groupby(lambda x: x.split('_')[-1], axis=1)
TUR_agg_df = pd.concat([group.mean() for name, group in TUR_df])

TUR_df = pd.DataFrame(TUR_agg_df.items(), columns=['group', 'value'])
TUR_df['statistic'] = TUR_df['group'].apply(lambda x: x.split('_')[-1])
TUR_df['group'] = TUR_df['group'].apply(lambda x: x.split('_')[1])


SPM_df = feature.filter(regex='^SPM').groupby(lambda x: x.split('_')[-1], axis=1)
SPM_agg_df = pd.concat([group.mean() for name, group in SPM_df])

SPM_df = pd.DataFrame(SPM_agg_df.items(), columns=['group', 'value'])
SPM_df['statistic'] = SPM_df['group'].apply(lambda x: x.split('_')[-1])
SPM_df['group'] = SPM_df['group'].apply(lambda x: x.split('_')[1])


CHL_df = feature.filter(regex='^CHL').groupby(lambda x: x.split('_')[-1], axis=1)
CHL_agg_df = pd.concat([group.mean() for name, group in CHL_df])

CHL_df = pd.DataFrame(CHL_agg_df.items(), columns=['group', 'value'])
CHL_df['statistic'] = CHL_df['group'].apply(lambda x: x.split('_')[-1])
CHL_df['group'] = CHL_df['group'].apply(lambda x: x.split('_')[1])

# %%
sns.set_palette("Set2")

fig, (ax1, ax2, ax3) = plt.subplots(nrows=3, figsize=(15, 12), sharex=True)
plt.suptitle('Mean / Median / Quantile of TUR / SPM / CHL data around the point (all 6 types of pixels)')

sns.barplot(data=TUR_df, x='group', y='value', hue='statistic', ax=ax1)
ax1.legend_.set_title(None)
ax1.set(xlabel=None)
ax1.set(ylabel=None)
ax1.set_title('TUR')

sns.barplot(data=SPM_df, x='group', y='value', hue='statistic', ax=ax2)
ax2.set_title('SPM')
ax2.set(xlabel=None)
ax2.legend_.remove()

sns.barplot(data=CHL_df, x='group', y='value', hue='statistic', ax=ax3)
ax3.set_title('CHL')
ax3.set(xlabel='Pixels')
ax3.set(ylabel=None)
ax3.legend_.remove()

plt.show()

# %% [markdown]
# # 11x11 mean

# %%
df_11x11_mean = feature.iloc[:, :2].join(feature.iloc[:, -9:-6])
df_11x11_mean
# Out:
#               time                    site  TUR_11x11_mean  SPM_11x11_mean  \
# 0       2022-03-01                Ainsdale             NaN             NaN
# 1       2022-03-01                 Allonby             NaN             NaN
# 2       2022-03-01           Allonby_South             NaN             NaN
# 3       2022-03-01             Amble_Links             NaN             NaN
# 4       2022-03-01                 Anderby             NaN             NaN
# ...            ...                     ...             ...             ...
# 101905  2022-10-31              Withernsea             NaN             NaN
# 101906  2022-10-31  Wolvercote_Mill_Stream             NaN             NaN
# 101907  2022-10-31      Woolacombe_Village       34.662595       25.860545
# 101908  2022-10-31                Worthing             NaN             NaN
# 101909  2022-10-31               Yaverland             NaN             NaN
#
#         CHL_11x11_mean
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ...                ...
# 101905             NaN
# 101906             NaN
# 101907        6.887635
# 101908             NaN
# 101909             NaN
#
# [101910 rows x 5 columns]

# %%
print(df_11x11_mean.shape)
print(df_11x11_mean.isnull().sum())
# Out:
# (101910, 5)
# time                  0
# site                  0
# TUR_11x11_mean    73430
# SPM_11x11_mean    73430
# CHL_11x11_mean    73430
# dtype: int64

# %% [markdown]
# ## Bacteria&Ecoli count vs. SPM&TUR&CHL

# %%
df1 = pd.merge(df_11x11_mean, sample, on=['site','time'])
df1 = df1.dropna()
df1 = df1.rename({'intestinalEnterococciCount': 'IE_count', 'escherichiaColiCount': 'EC_count'}, axis=1)  # new method
df1
# Out:
#             time         site  TUR_11x11_mean  SPM_11x11_mean  CHL_11x11_mean  \
# 13    2022-05-03      Heacham       30.878169       19.843502        9.983449
# 28    2022-05-03    Tankerton       58.544528       43.341505        8.576487
# 30    2022-05-04      Allonby        5.243375        3.263275        4.141318
# 31    2022-05-04     Beadnell       12.917741       10.625786        6.884509
# 32    2022-05-04   Broadsands        1.662952        0.976596        1.527455
# ...          ...          ...             ...             ...             ...
# 2526  2022-09-21   Sandymouth        2.888979        1.717045        4.342654
# 2527  2022-09-21      Shaldon        7.304994        4.430155        4.880118
# 2528  2022-09-21  Summerleaze        9.577234        6.355938        5.521259
# 2556  2022-09-23     Leysdown       47.984569       33.167467        9.652560
# 2559  2022-09-23    Sheerness       29.454085       17.691669        9.247976
#
#       IE_count  EC_count
# 13          10        10
# 28          10        45
# 30          18        36
# 31          10        10
# 32          10        10
# ...        ...       ...
# 2526        10        10
# 2527        18        10
# 2528        10        10
# 2556        27        18
# 2559        10        18
#
# [764 rows x 7 columns]

# %%
sns.pairplot(df1[["SPM_11x11_mean", "TUR_11x11_mean", "CHL_11x11_mean","IE_count", "EC_count"]], 
             diag_kind="kde",
             plot_kws=dict(marker="+", linewidth=1),
             diag_kws=dict(fill=False),
             corner=True)
plt.show()

# %%
methods = ['pearson', 'kendall', 'spearman']
for m in methods:
    corr_matrix = df1.corr(method=m)
    
    n = len(df1)
    df = n - 2

    results = []
    for col in ["IE_count", "EC_count"]:
        for row in ["SPM_11x11_mean", "TUR_11x11_mean", "CHL_11x11_mean"]:
            if row != col:
                corr_coef = corr_matrix.loc[row, col]
                t_value = corr_coef * ((n - 2) ** 0.5) / ((1 - corr_coef ** 2) ** 0.5)
                p_value = 2 * t.sf(abs(t_value), df)
                results.append((row, col, corr_coef, t_value, p_value))

    results_df = pd.DataFrame(results, columns=['Variable 1', 'Variable 2', 'Correlation Coefficient', 't-value', 'p-value'])

    print("\n\033[1m" + m + " correlation \033[0m")
    print(results_df)
# Out:
# pearson correlation
#        Variable 1 Variable 2  Correlation Coefficient   t-value   p-value
# 0  SPM_11x11_mean   IE_count                 0.000714  0.019705  0.984284
# 1  TUR_11x11_mean   IE_count                 0.001412  0.038984  0.968914
# 2  CHL_11x11_mean   IE_count                -0.006037 -0.166658  0.867683
# 3  SPM_11x11_mean   EC_count                 0.008524  0.235317  0.814026
# 4  TUR_11x11_mean   EC_count                 0.008590  0.237143  0.812610
# 5  CHL_11x11_mean   EC_count                 0.010367  0.286188  0.774812
#
# kendall correlation
#        Variable 1 Variable 2  Correlation Coefficient   t-value   p-value
# 0  SPM_11x11_mean   IE_count                 0.105786  2.936643  0.003418
# 1  TUR_11x11_mean   IE_count                 0.108543  3.014057  0.002663
# 2  CHL_11x11_mean   IE_count                 0.106812  2.965434  0.003117
# 3  SPM_11x11_mean   EC_count                 0.161523  4.518059  0.000007
# 4  TUR_11x11_mean   EC_count                 0.164646  4.607844  0.000005
# 5  CHL_11x11_mean   EC_count                 0.151337  4.226244  0.000027
#
# spearman correlation
#        Variable 1 Variable 2  Correlation Coefficient   t-value       p-value
# 0  SPM_11x11_mean   IE_count                 0.139877  3.899562  1.048678e-04
# 1  TUR_11x11_mean   IE_count                 0.143464  4.001618  6.905250e-05
# 2  CHL_11x11_mean   IE_count                 0.139252  3.881784  1.126786e-04
# 3  SPM_11x11_mean   EC_count                 0.215780  6.100174  1.684452e-09
# 4  TUR_11x11_mean   EC_count                 0.220257  6.233120  7.565770e-10
# 5  CHL_11x11_mean   EC_count                 0.201936  5.691570  1.795908e-08

# %% [markdown]
# There is significant correlation between the variables when using Kendall and Spearman correlation coefficients, while there is no significant correlation when using Pearson correlation coefficient.

# %% [markdown]
# ## Warnings vs. SPM&TUR&CHL

# %%
df2 = pd.merge(df_11x11_mean, riskforecasting, on=['site','time'])
df2 = df2.dropna()
df2['riskLevelLabel'].replace(['increased', 'normal'],[0, 1], inplace=True)
df2
# Out:
#              time           site  TUR_11x11_mean  SPM_11x11_mean  \
# 3      2022-03-17        Frinton      119.602328      123.807567
# 4      2022-03-17        Holland      100.306580      120.473114
# 5      2022-03-25       Saltburn       28.619714       20.838840
# 11     2022-04-28        Anderby       93.950831       70.109661
# 17     2022-04-28        Bexhill       19.778117       13.808608
# ...           ...            ...             ...             ...
# 22661  2022-09-30  Sutton-on-Sea      123.140806      110.938110
# 22663  2022-09-30      Tankerton       36.993651       26.043609
# 22670  2022-09-30         Walton      106.958851       87.916485
# 22673  2022-09-30          Wells       42.479288       31.916668
# 22677  2022-09-30     Winchelsea       23.628239       15.012895
#
#        CHL_11x11_mean                                          warning  \
# 3            8.214204  Pollution incident ended, no forecast available
# 4            8.594822  Pollution incident ended, no forecast available
# 5            8.042007  Pollution incident ended, no forecast available
# 11           8.508453         Pollution RIsk Forecasts will start soon
# 17          10.534637         Pollution RIsk Forecasts will start soon
# ...               ...                                              ...
# 22661        9.315174                  No pollution incidents reported
# 22663        8.131128                             No warnings in place
# 22670        7.594532                             No warnings in place
# 22673       13.717114                             No warnings in place
# 22677        4.302087                  No pollution incidents reported
#
#        riskLevelLabel
# 3                   1
# 4                   1
# 5                   1
# 11                  1
# 17                  1
# ...               ...
# 22661               1
# 22663               1
# 22670               1
# 22673               1
# 22677               1
#
# [6595 rows x 7 columns]

# %%
sns.set_palette("Set2")
grouped_warning = df2.groupby('warning')[['TUR_11x11_mean', 'SPM_11x11_mean', 'CHL_11x11_mean']].mean()
grouped_warning = grouped_warning.sort_values(by=['TUR_11x11_mean', 'SPM_11x11_mean', 'CHL_11x11_mean'], ascending=False)

grouped_warning.T.plot(kind='bar', figsize=(18, 5))
plt.title('Mean values of TUR_11x11_mean, SPM_11x11_mean, CHL_11x11_mean grouped by warning')
plt.xlabel('Warning')
plt.xticks(rotation=0)
plt.ylabel('Mean value')
plt.show()

# %%
fig, axes = plt.subplots(nrows=3, figsize=(12, 10), sharex=True)

sns.boxplot(y='warning', x='TUR_11x11_mean', data=df2, ax=axes[0])
sns.boxplot(y='warning', x='SPM_11x11_mean', data=df2, ax=axes[1])
sns.boxplot(y='warning', x='CHL_11x11_mean', data=df2, ax=axes[2])

plt.tight_layout()
plt.show()

# %% [markdown]
# ## riskLevelLabel vs. SPM&TUR&CHL

# %%
grouped_risk = df2.groupby('riskLevelLabel')[['TUR_11x11_mean', 'SPM_11x11_mean', 'CHL_11x11_mean']].mean()

grouped_risk.T.plot(kind='bar', figsize=(16, 6))
plt.title('Mean values of TUR_11x11_mean, SPM_11x11_mean, CHL_11x11_mean grouped by riskLevelLabel')
plt.xlabel('Warning')
plt.xticks(rotation=0)
plt.ylabel('Mean value')
plt.show()

# %%
fig, axes = plt.subplots(nrows=3, figsize=(12, 8), sharex=True)

sns.boxplot(y='riskLevelLabel', x='TUR_11x11_mean', data=df2, ax=axes[0])
sns.boxplot(y='riskLevelLabel', x='SPM_11x11_mean', data=df2, ax=axes[1])
sns.boxplot(y='riskLevelLabel', x='CHL_11x11_mean', data=df2, ax=axes[2])

plt.tight_layout()
plt.show()
